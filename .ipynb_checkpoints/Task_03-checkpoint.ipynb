# %% [markdown]
# # Task 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier

# %%
tweets_df = pd.read_csv("data/clean_processed_tweet.csv")

# %%
tweets_df.head()
# Out:
#    Unnamed: 0                 created_at      source  \
# 0           0  2022-08-07 22:31:20+00:00  ['source']
# 1           1  2022-08-07 22:31:16+00:00  ['source']
# 2           2  2022-08-07 22:31:07+00:00  ['source']
# 3           3  2022-08-07 22:31:06+00:00  ['source']
# 4           4  2022-08-07 22:31:04+00:00  ['source']
#
#                                        Original_Text  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1  RT @IndoPac_Info: #China's media explains the ...
# 2  China even cut off communication, they don't a...
# 3  Putin to #XiJinping : I told you my friend, Ta...
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...
#
#                                            full_text  sentiment      polarity  \
# 0  rt iameztoy extra random image lets focus one ...          0 -1.250000e-01
# 1  rt indopacinfo chinas media explains military ...          0 -1.000000e-01
# 2  china even cut communication dont anwer phonec...         -1  0.000000e+00
# 3  putin xijinping told friend taiwan vassal stat...          1  1.000000e-01
# 4  rt chinauncensored i’m sorry thought taiwan in...          0 -6.938894e-18
#
#    subjectivity lang  favorite_count  retweet_count possibly_sensitive  \
# 0      0.190625   en               0              2                NaN
# 1      0.100000   en               0            201                NaN
# 2      0.000000   en               0              0                NaN
# 3      0.350000   en               0              0                NaN
# 4      0.556250   en               0            381                NaN
#
#         hashtags    user_mentions           place
# 0           City        i_ameztoy             NaN
# 1  China, Taiwan     IndoPac_Info             NaN
# 2      XiJinping      ZelenskyyUa     Netherlands
# 3      XiJinping              NaN     Netherlands
# 4            NaN  ChinaUncensored  Ayent, Schweiz

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          999 non-null    int64
#  1   created_at          999 non-null    object
#  2   source              999 non-null    object
#  3   Original_Text       999 non-null    object
#  4   full_text           999 non-null    object
#  5   sentiment           999 non-null    int64
#  6   polarity            999 non-null    float64
#  7   subjectivity        999 non-null    float64
#  8   lang                999 non-null    object
#  9   favorite_count      999 non-null    int64
#  10  retweet_count       999 non-null    int64
#  11  possibly_sensitive  246 non-null    object
#  12  hashtags            877 non-null    object
#  13  user_mentions       875 non-null    object
#  14  place               568 non-null    object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 117.2+ KB

# %%
tweets_df.isna()
# Out:
#      Unnamed: 0  created_at  source  Original_Text  full_text  sentiment  \
# 0         False       False   False          False      False      False
# 1         False       False   False          False      False      False
# 2         False       False   False          False      False      False
# 3         False       False   False          False      False      False
# 4         False       False   False          False      False      False
# ..          ...         ...     ...            ...        ...        ...
# 994       False       False   False          False      False      False
# 995       False       False   False          False      False      False
# 996       False       False   False          False      False      False
# 997       False       False   False          False      False      False
# 998       False       False   False          False      False      False
#
#      polarity  subjectivity   lang  favorite_count  retweet_count  \
# 0       False         False  False           False          False
# 1       False         False  False           False          False
# 2       False         False  False           False          False
# 3       False         False  False           False          False
# 4       False         False  False           False          False
# ..        ...           ...    ...             ...            ...
# 994     False         False  False           False          False
# 995     False         False  False           False          False
# 996     False         False  False           False          False
# 997     False         False  False           False          False
# 998     False         False  False           False          False
#
#      possibly_sensitive  hashtags  user_mentions  place
# 0                  True     False          False   True
# 1                  True     False          False   True
# 2                  True     False          False  False
# 3                  True     False           True  False
# 4                  True      True          False  False
# ..                  ...       ...            ...    ...
# 994               False     False          False  False
# 995                True     False          False   True
# 996                True     False          False  False
# 997                True     False          False  False
# 998                True     False          False  False
#
# [999 rows x 15 columns]

# %%
tweets_df.isna()
# Out:
#      Unnamed: 0  created_at  source  Original_Text  full_text  sentiment  \
# 0         False       False   False          False      False      False
# 1         False       False   False          False      False      False
# 2         False       False   False          False      False      False
# 3         False       False   False          False      False      False
# 4         False       False   False          False      False      False
# ..          ...         ...     ...            ...        ...        ...
# 994       False       False   False          False      False      False
# 995       False       False   False          False      False      False
# 996       False       False   False          False      False      False
# 997       False       False   False          False      False      False
# 998       False       False   False          False      False      False
#
#      polarity  subjectivity   lang  favorite_count  retweet_count  \
# 0       False         False  False           False          False
# 1       False         False  False           False          False
# 2       False         False  False           False          False
# 3       False         False  False           False          False
# 4       False         False  False           False          False
# ..        ...           ...    ...             ...            ...
# 994     False         False  False           False          False
# 995     False         False  False           False          False
# 996     False         False  False           False          False
# 997     False         False  False           False          False
# 998     False         False  False           False          False
#
#      possibly_sensitive  hashtags  user_mentions  place
# 0                  True     False          False   True
# 1                  True     False          False   True
# 2                  True     False          False  False
# 3                  True     False           True  False
# 4                  True      True          False  False
# ..                  ...       ...            ...    ...
# 994               False     False          False  False
# 995                True     False          False   True
# 996                True     False          False  False
# 997                True     False          False  False
# 998                True     False          False  False
#
# [999 rows x 15 columns]

# %%
tweets_df.shape
# Out:
# (999, 15)

# %%
tweets_df.columns
# Out:
# Index(['Unnamed: 0', 'created_at', 'source', 'Original_Text', 'full_text',
#        'sentiment', 'polarity', 'subjectivity', 'lang', 'favorite_count',
#        'retweet_count', 'possibly_sensitive', 'hashtags', 'user_mentions',
#        'place'],
#       dtype='object')

# %%
tweets_df.dropna()
# Out:
#      Unnamed: 0                 created_at      source  \
# 5             5  2022-08-07 22:31:02+00:00  ['source']
# 36           36  2022-08-07 22:26:25+00:00  ['source']
# 39           39  2022-08-07 22:25:37+00:00  ['source']
# 43           43  2022-08-07 22:25:05+00:00  ['source']
# 48           48  2022-08-07 22:24:44+00:00  ['source']
# ..          ...                        ...         ...
# 960         960  2022-08-07 20:38:33+00:00  ['source']
# 963         963  2022-08-07 20:38:13+00:00  ['source']
# 965         965  2022-08-07 20:37:53+00:00  ['source']
# 967         967  2022-08-07 20:37:42+00:00  ['source']
# 994         994  2022-08-07 20:34:08+00:00  ['source']
#
#                                          Original_Text  \
# 5    RT @benedictrogers: We must not let this happe...
# 36   RT @ChinaInfo777: #PinkFloyd Roger Waters tell...
# 39   RT @WilliamYang120: "For too long, #Taiwan has...
# 43   RT @odisseoisback: #Corfu #Greece🇬🇷\n#Summer #...
# 48   RT @benedictrogers: We must not let this happe...
# ..                                                 ...
# 960  RT @Lavi4441: I think no caption need. #ChinaT...
# 963  RT @Fallen_x_King: True that\n#China #Taiwan #...
# 965  RT @AoxiPRNew: Taiwan now is an independent co...
# 967  It seems that @SpeakerPelosi had a very succes...
# 994  RT @RobertQ84643496: POLYMATECH INVESTS US$ 1 ...
#
#                                              full_text  sentiment  polarity  \
# 5    rt benedictrogers must let happen must ready m...          1     0.200
# 36   rt chinainfo777 pinkfloyd roger waters tells t...         -1     0.000
# 39   rt williamyang120 long taiwan bullied marginal...          0    -0.025
# 43   rt odisseoisback corfu greece summer beaches t...         -1     0.000
# 48   rt benedictrogers must let happen must ready m...          1     0.200
# ..                                                 ...        ...       ...
# 960  rt lavi4441 think caption need chinataiwancris...         -1     0.000
# 963  rt fallenxking true china taiwan wwiii httpstc...          1     0.350
# 965  rt aoxiprnew taiwan independent country pelosi...         -1     0.000
# 967  seems speakerpelosi successful trip taiwan htt...          1     1.000
# 994  rt robertq84643496 polymatech invests us 1 bil...         -1     0.000
#
#      subjectivity lang  favorite_count  retweet_count possibly_sensitive  \
# 5           0.500   en               0             36              False
# 36          0.000   en               0              5              False
# 39          0.200   en               0             84              False
# 43          0.000   en               0              2              False
# 48          0.500   en               0             36              False
# ..            ...  ...             ...            ...                ...
# 960         0.000   en               0           1249              False
# 963         0.650   en               0           2303              False
# 965         0.125   en               0             10              False
# 967         1.000   en               0              0              False
# 994         0.000   en               0              2              False
#
#                                               hashtags    user_mentions  \
# 5                                               Taiwan   benedictrogers
# 36                            PinkFloyd, Taiwan, China     ChinaInfo777
# 39                                              Taiwan   WilliamYang120
# 43   Corfu, Greece, Summer, Beaches, Travel, Excurs...    odisseoisback
# 48                                              Taiwan   benedictrogers
# ..                                                 ...              ...
# 960                   ChinaTaiwanCrisis, Taiwan, China         Lavi4441
# 963                               China, Taiwan, WWIII    Fallen_x_King
# 965  pelosivisittotaiwan, ccplies, chinesecommunist...        AoxiPRNew
# 967                                             Taiwan    SpeakerPelosi
# 994                                      semiconductor  RobertQ84643496
#
#                      place
# 5      Melbourne, Victoria
# 36            Florida, USA
# 39               Hong Kong
# 43                   Paris
# 48               Hong Kong
# ..                     ...
# 960  Hennessy in a TeaCup
# 963  Hennessy in a TeaCup
# 965                     村里
# 967    South East, England
# 994               Virginia
#
# [79 rows x 15 columns]

# %%
tweets_df["source"] = tweets_df["source"].str.replace(r"(\s*\<.*?\>\s*)", " ", regex=True).str.strip()

# %%
tweets_df
# Out:
#      Unnamed: 0                 created_at      source  \
# 0             0  2022-08-07 22:31:20+00:00  ['source']
# 1             1  2022-08-07 22:31:16+00:00  ['source']
# 2             2  2022-08-07 22:31:07+00:00  ['source']
# 3             3  2022-08-07 22:31:06+00:00  ['source']
# 4             4  2022-08-07 22:31:04+00:00  ['source']
# ..          ...                        ...         ...
# 994         994  2022-08-07 20:34:08+00:00  ['source']
# 995         995  2022-08-07 20:34:05+00:00  ['source']
# 996         996  2022-08-07 20:34:02+00:00  ['source']
# 997         997  2022-08-07 20:33:52+00:00  ['source']
# 998         998  2022-08-07 20:33:40+00:00  ['source']
#
#                                          Original_Text  \
# 0    RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1    RT @IndoPac_Info: #China's media explains the ...
# 2    China even cut off communication, they don't a...
# 3    Putin to #XiJinping : I told you my friend, Ta...
# 4    RT @ChinaUncensored: I’m sorry, I thought Taiw...
# ..                                                 ...
# 994  RT @RobertQ84643496: POLYMATECH INVESTS US$ 1 ...
# 995  RT @SpokespersonCHN: "#Taiwan is part of China...
# 996  RT @IndoPac_Info: From Chinese media:\n\n"#PLA...
# 997  RT @IndoPac_Info: 1) A Lithuanian delegation h...
# 998  RT @EpochOpinion: Opinion💭by Roger L. Simon\n\...
#
#                                              full_text  sentiment  \
# 0    rt iameztoy extra random image lets focus one ...          0
# 1    rt indopacinfo chinas media explains military ...          0
# 2    china even cut communication dont anwer phonec...         -1
# 3    putin xijinping told friend taiwan vassal stat...          1
# 4    rt chinauncensored i’m sorry thought taiwan in...          0
# ..                                                 ...        ...
# 994  rt robertq84643496 polymatech invests us 1 bil...         -1
# 995  rt spokespersonchn taiwan part china thats abs...          1
# 996  rt indopacinfo chinese media pla eastern theat...          0
# 997  rt indopacinfo 1 lithuanian delegation headed ...         -1
# 998  rt epochopinion opinionby roger l simon ccp ma...          0
#
#          polarity  subjectivity lang  favorite_count  retweet_count  \
# 0   -1.250000e-01      0.190625   en               0              2
# 1   -1.000000e-01      0.100000   en               0            201
# 2    0.000000e+00      0.000000   en               0              0
# 3    1.000000e-01      0.350000   en               0              0
# 4   -6.938894e-18      0.556250   en               0            381
# ..            ...           ...  ...             ...            ...
# 994  0.000000e+00      0.000000   en               0              2
# 995  1.333333e-01      0.433333   en               0            669
# 996 -5.000000e-02      0.050000   en               0             60
# 997  0.000000e+00      0.000000   en               0             66
# 998 -4.062500e-01      0.750000   en               0             21
#
#     possibly_sensitive       hashtags                user_mentions  \
# 0                  NaN           City                    i_ameztoy
# 1                  NaN  China, Taiwan                 IndoPac_Info
# 2                  NaN      XiJinping                  ZelenskyyUa
# 3                  NaN      XiJinping                          NaN
# 4                  NaN            NaN              ChinaUncensored
# ..                 ...            ...                          ...
# 994              False  semiconductor              RobertQ84643496
# 995                NaN         Taiwan              SpokespersonCHN
# 996                NaN    PLA, Taiwan                 IndoPac_Info
# 997                NaN         Taiwan                 IndoPac_Info
# 998                NaN            CCP  EpochOpinion, SpeakerPelosi
#
#                    place
# 0                    NaN
# 1                    NaN
# 2            Netherlands
# 3            Netherlands
# 4         Ayent, Schweiz
# ..                   ...
# 994             Virginia
# 995                  NaN
# 996  奈良県 奈良市 Nara, JAPAN
# 997  奈良県 奈良市 Nara, JAPAN
# 998    Somewhere, U.S.A.
#
# [999 rows x 15 columns]

# %%
labels = ['neutral', 'positive', 'negative']

neutral_count =  len(tweets_df[tweets_df['polarity'] > 0])
positive_count = len(tweets_df[tweets_df['polarity'] == 0])
negative_count = len(tweets_df[tweets_df['polarity'] <0])
sizes = [neutral_count, positive_count, negative_count]
# Create a figure for 2 subplots (1 row, 2 columns)
fig, ax = plt.subplots(1, 2, figsize = (10,4))

# Create a bar plot of score column
ax[0].bar(x=labels, height=[neutral_count, positive_count, negative_count], color='orange')
ax[0].set_title('Barchart of score column')
ax[0].set_xticklabels(labels, rotation=90)

# Create a pie chart of score column based on neutral, positive or negative

ax[1].pie(sizes,labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax[1].set_title('Piechart of score column')
ax[1].legend(labels)

# Add a title to the Figure
fig.suptitle('Score column plots')

# Show the figure
fig.show()

# %% [markdown]
# ## preprocessing

# %%
tweets_df.insert(4,column = 'clean_text',value = tweets_df['Original_Text'])

# %%
tweets_df.head()
# Out:
#    Unnamed: 0                 created_at      source  \
# 0           0  2022-08-07 22:31:20+00:00  ['source']
# 1           1  2022-08-07 22:31:16+00:00  ['source']
# 2           2  2022-08-07 22:31:07+00:00  ['source']
# 3           3  2022-08-07 22:31:06+00:00  ['source']
# 4           4  2022-08-07 22:31:04+00:00  ['source']
#
#                                        Original_Text  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1  RT @IndoPac_Info: #China's media explains the ...
# 2  China even cut off communication, they don't a...
# 3  Putin to #XiJinping : I told you my friend, Ta...
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...
#
#                                           clean_text  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1  RT @IndoPac_Info: #China's media explains the ...
# 2  China even cut off communication, they don't a...
# 3  Putin to #XiJinping : I told you my friend, Ta...
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...
#
#                                            full_text  sentiment      polarity  \
# 0  rt iameztoy extra random image lets focus one ...          0 -1.250000e-01
# 1  rt indopacinfo chinas media explains military ...          0 -1.000000e-01
# 2  china even cut communication dont anwer phonec...         -1  0.000000e+00
# 3  putin xijinping told friend taiwan vassal stat...          1  1.000000e-01
# 4  rt chinauncensored i’m sorry thought taiwan in...          0 -6.938894e-18
#
#    subjectivity lang  favorite_count  retweet_count possibly_sensitive  \
# 0      0.190625   en               0              2                NaN
# 1      0.100000   en               0            201                NaN
# 2      0.000000   en               0              0                NaN
# 3      0.350000   en               0              0                NaN
# 4      0.556250   en               0            381                NaN
#
#         hashtags    user_mentions           place
# 0           City        i_ameztoy             NaN
# 1  China, Taiwan     IndoPac_Info             NaN
# 2      XiJinping      ZelenskyyUa     Netherlands
# 3      XiJinping              NaN     Netherlands
# 4            NaN  ChinaUncensored  Ayent, Schweiz

# %%
tweets_df
# Out:
#      Unnamed: 0                 created_at      source  \
# 0             0  2022-08-07 22:31:20+00:00  ['source']
# 1             1  2022-08-07 22:31:16+00:00  ['source']
# 2             2  2022-08-07 22:31:07+00:00  ['source']
# 3             3  2022-08-07 22:31:06+00:00  ['source']
# 4             4  2022-08-07 22:31:04+00:00  ['source']
# ..          ...                        ...         ...
# 994         994  2022-08-07 20:34:08+00:00  ['source']
# 995         995  2022-08-07 20:34:05+00:00  ['source']
# 996         996  2022-08-07 20:34:02+00:00  ['source']
# 997         997  2022-08-07 20:33:52+00:00  ['source']
# 998         998  2022-08-07 20:33:40+00:00  ['source']
#
#                                          Original_Text  \
# 0    RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1    RT @IndoPac_Info: #China's media explains the ...
# 2    China even cut off communication, they don't a...
# 3    Putin to #XiJinping : I told you my friend, Ta...
# 4    RT @ChinaUncensored: I’m sorry, I thought Taiw...
# ..                                                 ...
# 994  RT @RobertQ84643496: POLYMATECH INVESTS US$ 1 ...
# 995  RT @SpokespersonCHN: "#Taiwan is part of China...
# 996  RT @IndoPac_Info: From Chinese media:\n\n"#PLA...
# 997  RT @IndoPac_Info: 1) A Lithuanian delegation h...
# 998  RT @EpochOpinion: Opinion💭by Roger L. Simon\n\...
#
#                                             clean_text  \
# 0    RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1    RT @IndoPac_Info: #China's media explains the ...
# 2    China even cut off communication, they don't a...
# 3    Putin to #XiJinping : I told you my friend, Ta...
# 4    RT @ChinaUncensored: I’m sorry, I thought Taiw...
# ..                                                 ...
# 994  RT @RobertQ84643496: POLYMATECH INVESTS US$ 1 ...
# 995  RT @SpokespersonCHN: "#Taiwan is part of China...
# 996  RT @IndoPac_Info: From Chinese media:\n\n"#PLA...
# 997  RT @IndoPac_Info: 1) A Lithuanian delegation h...
# 998  RT @EpochOpinion: Opinion💭by Roger L. Simon\n\...
#
#                                              full_text  sentiment  \
# 0    rt iameztoy extra random image lets focus one ...          0
# 1    rt indopacinfo chinas media explains military ...          0
# 2    china even cut communication dont anwer phonec...         -1
# 3    putin xijinping told friend taiwan vassal stat...          1
# 4    rt chinauncensored i’m sorry thought taiwan in...          0
# ..                                                 ...        ...
# 994  rt robertq84643496 polymatech invests us 1 bil...         -1
# 995  rt spokespersonchn taiwan part china thats abs...          1
# 996  rt indopacinfo chinese media pla eastern theat...          0
# 997  rt indopacinfo 1 lithuanian delegation headed ...         -1
# 998  rt epochopinion opinionby roger l simon ccp ma...          0
#
#          polarity  subjectivity lang  favorite_count  retweet_count  \
# 0   -1.250000e-01      0.190625   en               0              2
# 1   -1.000000e-01      0.100000   en               0            201
# 2    0.000000e+00      0.000000   en               0              0
# 3    1.000000e-01      0.350000   en               0              0
# 4   -6.938894e-18      0.556250   en               0            381
# ..            ...           ...  ...             ...            ...
# 994  0.000000e+00      0.000000   en               0              2
# 995  1.333333e-01      0.433333   en               0            669
# 996 -5.000000e-02      0.050000   en               0             60
# 997  0.000000e+00      0.000000   en               0             66
# 998 -4.062500e-01      0.750000   en               0             21
#
#     possibly_sensitive       hashtags                user_mentions  \
# 0                  NaN           City                    i_ameztoy
# 1                  NaN  China, Taiwan                 IndoPac_Info
# 2                  NaN      XiJinping                  ZelenskyyUa
# 3                  NaN      XiJinping                          NaN
# 4                  NaN            NaN              ChinaUncensored
# ..                 ...            ...                          ...
# 994              False  semiconductor              RobertQ84643496
# 995                NaN         Taiwan              SpokespersonCHN
# 996                NaN    PLA, Taiwan                 IndoPac_Info
# 997                NaN         Taiwan                 IndoPac_Info
# 998                NaN            CCP  EpochOpinion, SpeakerPelosi
#
#                    place
# 0                    NaN
# 1                    NaN
# 2            Netherlands
# 3            Netherlands
# 4         Ayent, Schweiz
# ..                   ...
# 994             Virginia
# 995                  NaN
# 996  奈良県 奈良市 Nara, JAPAN
# 997  奈良県 奈良市 Nara, JAPAN
# 998    Somewhere, U.S.A.
#
# [999 rows x 16 columns]

# %%
tweets_df = tweets_df[['Original_Text','clean_text','polarity']]

# %%
def text_category (polarity):
    if polarity > 0:
        return 'positive'
    if polarity < 0:
        return 'negative'
    else:
        return 'neutral'

# %%
score= pd.Series([text_category(row_value) for row_value in tweets_df['polarity']])
tweets_df = pd.concat([tweets_df, score.rename('sentiment')], axis=1)
tweets_df.head()
# Out:
#                                        Original_Text  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1  RT @IndoPac_Info: #China's media explains the ...
# 2  China even cut off communication, they don't a...
# 3  Putin to #XiJinping : I told you my friend, Ta...
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...
#
#                                           clean_text      polarity sentiment
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets... -1.250000e-01  negative
# 1  RT @IndoPac_Info: #China's media explains the ... -1.000000e-01  negative
# 2  China even cut off communication, they don't a...  0.000000e+00   neutral
# 3  Putin to #XiJinping : I told you my friend, Ta...  1.000000e-01  positive
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw... -6.938894e-18  negative

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import gensim
from gensim.models import CoherenceModel
from gensim import corpora
from pprint import pprint
import string
import re
import emoji
import nltk
nltk.download('words')
words = set(nltk.corpus.words.words())
# Out:
# [nltk_data] Downloading package words to /Users/biruk/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def cleaner(tweet):
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI) #Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ") #Remove hashtag sign but keep the text
    tweet = " ".join(w for w in nltk.wordpunct_tokenize(tweet) \
         if w.lower() in words or not w.isalpha())
    return tweet

tweets_df['clean_text'] = tweets_df['Original_Text'].map(lambda x: cleaner(x))
tweets_df.head()
# Out:
#                                        Original_Text  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1  RT @IndoPac_Info: #China's media explains the ...
# 2  China even cut off communication, they don't a...
# 3  Putin to #XiJinping : I told you my friend, Ta...
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...
#
#                                           clean_text      polarity sentiment
# 0  : Extra random image ( I ): focus in one very ... -1.250000e-01  negative
# 1  : China ' s media the military for each area o... -1.000000e-01  negative
# 2  China even cut off communication , they don ' ...  0.000000e+00   neutral
# 3  to : I told you my friend , will be a vassal s...  1.000000e-01  positive
# 4  : I ’ m sorry , I thought was an independent c... -6.938894e-18  negative

# %%
class PrepareData:
  def __init__(self,df):
    self.df=df
    
  def preprocess_data(self):
    #tweets_df = self.df.loc[self.df['lang'] =="en"]

    
    #text Preprocessing
    tweets_df['clean_text']=tweets_df['clean_text'].astype(str)
    tweets_df['clean_text'] = tweets_df['clean_text'].apply(lambda x: x.lower())
    tweets_df['clean_text']= tweets_df['clean_text'].apply(lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))
    
    #Converting tweets to list of words For feature engineering
    sentence_list = [tweet for tweet in tweets_df['clean_text']]
    word_list = [sent.split() for sent in sentence_list]
    # print(word_list)

    #Create dictionary which contains Id and word 
    word_to_id = corpora.Dictionary(word_list) #generate unique tokens
    #  we can see the word to unique integer mapping
    # print(word_to_id.token2id)
    # using bag of words(bow), we create a corpus that contains the word id and its frequency in each document.
    corpus_1= [word_to_id.doc2bow(tweet) for tweet in word_list]
    # TFIDF

    return tweets_df['clean_text'],word_list, word_to_id, corpus_1

# %%
PrepareData_obj=PrepareData(tweets_df)
tweets_df['clean_text'],word_list ,id2word,corpus=PrepareData_obj.preprocess_data()

# %%
tweets_df
# Out:
#                                          Original_Text  \
# 0    RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1    RT @IndoPac_Info: #China's media explains the ...
# 2    China even cut off communication, they don't a...
# 3    Putin to #XiJinping : I told you my friend, Ta...
# 4    RT @ChinaUncensored: I’m sorry, I thought Taiw...
# ..                                                 ...
# 994  RT @RobertQ84643496: POLYMATECH INVESTS US$ 1 ...
# 995  RT @SpokespersonCHN: "#Taiwan is part of China...
# 996  RT @IndoPac_Info: From Chinese media:\n\n"#PLA...
# 997  RT @IndoPac_Info: 1) A Lithuanian delegation h...
# 998  RT @EpochOpinion: Opinion💭by Roger L. Simon\n\...
#
#                                             clean_text      polarity sentiment
# 0     extra random image  i  focus in one very spec... -1.250000e-01  negative
# 1     china  s media the military for each area of ... -1.000000e-01  negative
# 2    china even cut off communication  they don  t ...  0.000000e+00   neutral
# 3    to  i told you my friend  will be a vassal sta...  1.000000e-01  positive
# 4     i ’ m sorry  i thought was an independent cou... -6.938894e-18  negative
# ..                                                 ...           ...       ...
# 994   us  1 billion in semiconductor chips source  ...  0.000000e+00   neutral
# 995    is part of china  that  s been absolutely ac...  1.333333e-01  positive
# 996   from media   eastern theater command joint mi... -5.000000e-02  negative
# 997   1  a delegation headed by minister of transpo...  0.000000e+00   neutral
# 998   opinion 💭 by roger l  the may be evil but the... -4.062500e-01  negative
#
# [999 rows x 4 columns]

# %%
id_words = [[(id2word[id], count) for id, count in line] for line in corpus]

# %%
print(id_words)
# Out:
# [[('city', 1), ('coast', 1), ('district', 1), ('extra', 1), ('focus', 1), ('i', 1), ('image', 1), ('in', 1), ('of', 1), ('one', 1), ('random', 1), ('specific', 1), ('ta', 1), ('the', 1), ('very', 1), ('western', 1), ('zone', 1), ('…', 1)], [('in', 2), ('of', 1), ('the', 5), ('…', 1), ('area', 1), ('china', 1), ('each', 1), ('for', 1), ('media', 1), ('military', 1), ('pi', 1), ('read', 1), ('s', 1), ('strait', 1)], [('the', 2), ('china', 1), ('s', 1), ('ask', 1), ('but', 1), ('change', 1), ('clown', 1), ('communication', 1), ('cut', 1), ('don', 1), ('even', 1), ('from', 1), ('here', 1), ('mind', 1), ('off', 1), ('stage', 1), ('t', 1), ('they', 1), ('to', 2), ('us', 1)], [('i', 2), ('the', 1), ('china', 1), ('s', 1), ('but', 1), ('to', 2), ('a', 1), ('be', 1), ('friend', 1), ('it', 1), ('like', 1), ('model', 1), ('much', 1), ('my', 1), ('open', 1), ('state', 1), ('told', 1), ('took', 1), ('vassal', 1), ('will', 1), ('you', 2)], [('i', 2), ('…', 1), ('military', 1), ('it', 1), ('an', 1), ('because', 1), ('country', 1), ('currency', 1), ('d', 1), ('government', 1), ('had', 1), ('independent', 1), ('its', 1), ('m', 1), ('own', 1), ('sorry', 1), ('thought', 1), ('travel', 1), ('was', 1), ('’', 1)], [('be', 1), ('defend', 1), ('happen', 1), ('let', 1), ('must', 3), ('not', 1), ('ready', 1), ('this', 1), ('we', 3)], [('of', 1), ('the', 1), ('…', 1), ('country', 1), ('can', 1), ('connive', 1), ('extremely', 1), ('kind', 1), ('offensive', 1), ('official', 1), ('on', 1), ('street', 1), ('such', 1), ('what', 1)], [('of', 1), ('…', 1), ('china', 1), ('a', 1), ('you', 1), ('and', 2), ('dont', 1), ('educate', 1), ('go', 1), ('if', 1), ('is', 1), ('know', 1), ('part', 1), ('roger', 1), ('singer', 1), ('that', 1), ('yoursel', 1)], [('the', 1), ('…', 1), ('china', 2), ('s', 2), ('a', 1), ('country', 1), ('on', 2), ('is', 1), ('been', 1), ('never', 1), ('position', 1), ('question', 1), ('there', 1), ('wang', 1)], [('the', 1), ('…', 1), ('china', 1), ('s', 1), ('to', 2), ('us', 1), ('was', 1), ('ambassador', 1), ('by', 1), ('detailed', 1), ('house', 1), ('nancy', 1), ('opposed', 1), ('speaker', 1), ('visit', 1), ('why', 1)], [('in', 1), ('the', 3), ('…', 1), ('to', 1), ('us', 1), ('on', 1), ('by', 1), ('around', 1), ('latest', 1), ('made', 1), ('massive', 1), ('response', 1), ('serious', 1), ('when', 1)], [('the', 1), ('china', 1), ('and', 1), ('list', 1)], [('of', 1), ('china', 1), ('s', 1), ('a', 1), ('on', 2), ('4th', 1), ('august', 1), ('good', 1), ('missile', 1)], [('of', 1), ('…', 1), ('china', 1), ('s', 1), ('t', 1), ('they', 1), ('not', 1), ('and', 1), ('is', 1), ('part', 1), ('roger', 1), ('that', 1), ('been', 1), ('by', 1), ('absolutely', 1), ('accepted', 1), ('re', 1)], [('in', 1), ('…', 1), ('and', 1), ('that', 1), ('there', 1), ('38', 1), ('67', 1), ('are', 1), ('do', 1), ('dumpling', 1), ('noodle', 1), ('show', 1)], [('the', 4), ('…', 1), ('for', 1), ('because', 1), ('is', 1), ('about', 1), ('az001', 1), ('coin', 1), ('future', 2), ('goodness', 1), ('now', 1), ('project', 1), ('right', 1), ('up', 1), ('win', 1)], [('china', 2), ('military', 1), ('s', 1), ('to', 1), ('us', 1), ('a', 1), ('close', 1), ('diplomacy', 1), ('draw', 1), ('ever', 1)], [('the', 1), ('…', 1), ('china', 1), ('for', 1), ('a', 1), ('and', 1), ('are', 1), ('now', 1), ('building', 1), ('colonial', 1), ('false', 1), ('former', 1), ('g7', 1), ('just', 1), ('self', 1), ('war', 1), ('with', 1)], [('…', 1), ('travel', 1), ('on', 1), ('availability', 1), ('check', 1), ('excursion', 1), ('summer', 1), ('🇬🇷', 1), ('👉', 1)], [('china', 1), ('for', 2), ('off', 1), ('with', 1), ('17', 1), ('27', 1), ('89us', 1), ('c', 1), ('computer', 1), ('condenser', 1), ('converter', 1), ('filter', 1), ('gaming', 1), ('microphone', 2), ('phone', 1), ('pop', 1), ('russia', 1), ('stand', 1), ('studio', 1), ('type', 1)], [('of', 1), ('the', 2), ('…', 1), ('china', 1), ('military', 1), ('from', 1), ('to', 1), ('it', 1), ('and', 1), ('now', 1), ('up', 1), ('air', 1), ('alarm', 1), ('as', 1), ( ...

# %% [markdown]
# ## Topic Modelling

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.057*"the" + 0.052*"…" + 0.039*"and" + 0.026*"of" + 0.024*"to" + '
#   '0.022*"china" + 0.016*"in" + 0.015*"now" + 0.015*"do" + 0.015*"from"'),
#  (1,
#   '0.041*"…" + 0.039*"the" + 0.034*"her" + 0.028*"to" + 0.028*"and" + '
#   '0.027*"for" + 0.024*"s" + 0.023*"us" + 0.022*"nancy" + 0.021*"’"'),
#  (2,
#   '0.071*"of" + 0.047*"china" + 0.045*"…" + 0.044*"is" + 0.037*"if" + '
#   '0.036*"and" + 0.036*"the" + 0.034*"that" + 0.033*"part" + 0.032*"you"'),
#  (3,
#   '0.039*"to" + 0.034*"a" + 0.031*"is" + 0.027*"the" + 0.026*"…" + 0.025*"i" + '
#   '0.023*"on" + 0.022*"in" + 0.021*"it" + 0.018*"china"'),
#  (4,
#   '0.053*"the" + 0.046*"china" + 0.030*"in" + 0.028*"s" + 0.027*"on" + '
#   '0.025*"a" + 0.024*"…" + 0.020*"is" + 0.018*"to" + 0.014*"of"')]

# %%
pprint(lda_model.show_topics(formatted=False))
# Out:
# [(0,
#   [('the', 0.057138246),
#    ('…', 0.052068982),
#    ('and', 0.03852734),
#    ('of', 0.026293088),
#    ('to', 0.023704508),
#    ('china', 0.022190101),
#    ('in', 0.01591547),
#    ('now', 0.015399468),
#    ('do', 0.015286742),
#    ('from', 0.0151316775)]),
#  (1,
#   [('…', 0.04135065),
#    ('the', 0.039468724),
#    ('her', 0.03355176),
#    ('to', 0.028148616),
#    ('and', 0.027848475),
#    ('for', 0.027346617),
#    ('s', 0.023505237),
#    ('us', 0.023218585),
#    ('nancy', 0.021610798),
#    ('’', 0.021010626)]),
#  (2,
#   [('of', 0.071029395),
#    ('china', 0.046687912),
#    ('…', 0.045249127),
#    ('is', 0.04399108),
#    ('if', 0.036876757),
#    ('and', 0.035698272),
#    ('the', 0.035635505),
#    ('that', 0.034210093),
#    ('part', 0.033290565),
#    ('you', 0.032143142)]),
#  (3,
#   [('to', 0.039402198),
#    ('a', 0.03421746),
#    ('is', 0.030835478),
#    ('the', 0.02716019),
#    ('…', 0.026199292),
#    ('i', 0.025360713),
#    ('on', 0.023409918),
#    ('in', 0.022169018),
#    ('it', 0.020701285),
#    ('china', 0.017903501)]),
#  (4,
#   [('the', 0.05308535),
#    ('china', 0.04589361),
#    ('in', 0.030473812),
#    ('s', 0.027651),
#    ('on', 0.02663166),
#    ('a', 0.024603585),
#    ('…', 0.023617031),
#    ('is', 0.02012225),
#    ('to', 0.017661931),
#    ('of', 0.014059717)])]

# %% [markdown]
# ## Model Analysis

# %%
import pyLDAvis.gensim_models as gensimvis
import pickle 
import pyLDAvis
# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_prepared = gensimvis.prepare(lda_model, corpus, id2word)
LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.201771 -0.173880       1        1  25.220244
# 1     -0.214941 -0.119853       2        1  24.499575
# 3      0.118712  0.138591       3        1  17.580020
# 4     -0.034407  0.106351       4        1  17.288206
# 0     -0.071134  0.048791       5        1  15.411954, topic_info=     Term        Freq       Total Category  logprob  loglift
# 215   her  141.000000  141.000000  Default  30.0000  30.0000
# 101  part  144.000000  144.000000  Default  29.0000  29.0000
# 99     is  343.000000  343.000000  Default  28.0000  28.0000
# 98     if  186.000000  186.000000  Default  27.0000  27.0000
# 34    don  127.000000  127.000000  Default  26.0000  26.0000
# ..    ...         ...         ...      ...      ...      ...
# 7      in   42.076789  237.952726   Topic5  -4.1405   0.1375
# 104  that   39.548097  217.908492   Topic5  -4.2024   0.1635
# 48     it   30.082322  114.250914   Topic5  -4.4760   0.5356
# 192  next   24.039555   41.213446   Topic5  -4.7003   1.3310
# 113    by   26.705893  185.104917   Topic5  -4.5951  -0.0660
#
# [275 rows x 6 columns], token_table=      Topic      Freq   Term
# term
# 410       2  0.989490      1
# 819       3  0.968080   2021
# 198       2  0.981180      3
# 136       5  0.982870     38
# 425       2  0.981246      4
# ...     ...       ...    ...
# 403       1  0.072069     🇹🇼
# 403       2  0.036035     🇹🇼
# 403       3  0.900868     🇹🇼
# 780       3  0.903493     👉👉
# 197       5  0.979442  🚨🇨🇳🇹🇼
#
# [298 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 2, 4, 5, 1])

# %%
import sys
print(sys.executable)
from wordcloud import WordCloud
# Out:
# /Users/biruk/opt/anaconda3/bin/python

# %%
long_string = ','.join(list(tweets_df['clean_text'].values))

wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F9C29EDCCD0>

# %% [markdown]
# ## Sentiment Analysis
